# %%
import function_ramsey_numbers as ram

# %%
# %%time
p = ram.Rams_comp_update3_print(3,3)
print(p)
# Out:
# Graph:
# []
# Graph:
# [(0, 1)]
# Graph:
# [(0, 1), (0, 2), (1, 2)]
# Graph:
# [(0, 1), (0, 2), (1, 2)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# Graph:
# [(0, 1), (0, 2), (0, 3), (0, 4), (1, 2), (1, 3), (1, 4), (2, 3), (2, 4), (3, 4)]
# Graph:
# ...

# %%
r11 = ram.Rams_comp_update3(1,1)
r12 = ram.Rams_comp_update3(1,2)
r13 = ram.Rams_comp_update3(1,3)
r14 = ram.Rams_comp_update3(1,4)

# %%
r21 = r12
r22 = ram.Rams_comp_update3(2,2)
r23 = ram.Rams_comp_update3(2,3)
r24 = ram.Rams_comp_update3(2,4)

# %%
# %%time
r31 = r13
r32 = r23
r33 = ram.Rams_comp_update3(3,3)

# %%
# %%time
r34 = ram.Rams_comp_update3(3,4)

# %%
# %%time
r41 = r14
r42 = r24
r43 = r34
r44 = ram.Rams_comp_update3(4,4)

# %%
from prettytable import PrettyTable

# Create a PrettyTable object
table = PrettyTable()

# Define the column names
table.field_names = [" l/r", " r = 1", "r = 2", "r = 3", "r=4"]

# Add rows to the table
table.add_row(["l = 1", r11 , r12, r13, r14 ])
table.add_row(["l = 2", r21 , r22, r23, r24 ])
table.add_row(["l = 3", r31 , r32, r33, r34 ])
table.add_row(["l = 4", r41 , r42, r43, r44 ])

# Print the table
print(table)
